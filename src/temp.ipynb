# %%
from pprint import pprint

import pandas as pd

# %%
data = "/home/artur/Desktop/FA/data/NAKO_tabular/30k_metadata/NAKO-536_2023-07-13_Erstuntersuchung_MRT_PSN_wie_194.csv"

df = pd.read_csv(data, sep=";", encoding="latin1")

feature_dict = {feat: None for feat in df.columns}
pprint(feature_dict)
# Out:
# {'BD01': None,
#  'BD02': None,
#  'BD035': None,
#  'BD04': None,
#  'BD05': None,
#  'BD14': None,
#  'BD17': None,
#  'ID': None,
#  'SE01': None,
#  'SE02': None,
#  'a_an_metdm1_age': None,
#  'a_ethn1': None,
#  'a_ethn2': None,
#  'a_ms_age_arthueft': None,
#  'a_ms_age_artknie': None,
#  'a_ms_age_ost': None,
#  'a_sel_age_bechterew': None,
#  'anthro_fettmasse': None,
#  'anthro_gew': None,
#  'anthro_groe': None,
#  'anthro_hueftumfang': None,
#  'anthro_impedanz': None,
#  'anthro_phasenwinkel': None,
#  'anthro_reaktanz': None,
#  'anthro_resistanz': None,
#  'anthro_taillenumfang': None,
#  'basis_age': None,
#  'basis_sex': None,
#  'basis_uort': None,
#  'd_alk1': None,
#  'd_alk2r1': None,
#  'd_an_cv_1': None,
#  'd_an_cv_2': None,
#  'd_an_cv_3': None,
#  'd_an_cv_4': None,
#  'd_an_cv_5': None,
#  'd_an_cv_6': None,
#  'd_an_lungasth2': None,
#  'd_an_lungcopd1_a': None,
#  'd_an_lungcopd2': None,
#  'd_an_met_1': None,
#  'd_an_met_2': None,
# ...
